# %%
import pandas as pd
import regex
import numpy as np

# %% [markdown]
# # Renewable Energy

# %% [markdown]
# ## Exploration

# %%
urlfile = 'https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv'
ourworldindata = pd.read_csv(urlfile)

# %%
ourworldindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17432 entries, 0 to 17431
# Columns: 122 entries, iso_code to wind_energy_per_capita
# dtypes: float64(119), int64(1), object(2)
# memory usage: 16.2+ MB

# %%
# ourworldindata[ourworldindata.columns[:40]].info()
# ourworldindata[ourworldindata.columns[40:80]].info()
# ourworldindata[ourworldindata.columns[80:122]].info()

# %%
ourworldindata_biofuel = ourworldindata.filter(regex='^biofuel')
ourworldindata_biofuel
# Out:
#        biofuel_share_elec  biofuel_elec_per_capita  biofuel_cons_change_pct  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
# ...                   ...                      ...                      ...
# 17427               1.363                    9.265                      NaN
# 17428               2.154                   10.478                      NaN
# 17429               2.066                   10.606                      NaN
# 17430               2.048                   12.951                      NaN
# 17431               2.285                   14.112                      NaN
#
#        biofuel_share_energy  biofuel_cons_change_twh  biofuel_consumption  \
# 0                       NaN                      NaN                  NaN
# 1                       NaN                      NaN                  NaN
# 2                       NaN                      NaN                  NaN
# 3                       NaN                      NaN                  NaN
# 4                       NaN                      NaN                  NaN
# ...                     ...                      ...                  ...
# 17427                   NaN                      0.0                  0.0
# 17428                   NaN                      0.0                  0.0
# 17429                   NaN                      0.0                  0.0
# 17430                   NaN                      0.0                  0.0
# 17431                   NaN                      0.0                  0.0
#
#        biofuel_cons_per_capita  biofuel_electricity
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# ...                        ...                  ...
# 17427                      0.0                0.128
# 17428                      0.0                0.147
# 17429                      0.0                0.151
# 17430                      0.0                0.187
# 17431                      0.0                0.207
#
# [17432 rows x 8 columns]

# %%
hydro_cols = [col for col in ourworldindata.columns if 'hydro' in col]
ourworldindata_hydro = ourworldindata[hydro_cols]
ourworldindata_hydro
# Out:
#        hydro_electricity  hydro_share_elec  hydro_cons_change_pct  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# ...                  ...               ...                    ...
# 17427              4.940            52.622                    NaN
# 17428              2.955            43.291                    NaN
# 17429              3.929            53.752                    NaN
# 17430              5.000            54.746                    NaN
# 17431              5.020            55.494                    NaN
#
#        hydro_share_energy  hydro_cons_change_twh  hydro_consumption  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
# ...                   ...                    ...                ...
# 17427                 NaN                    NaN                NaN
# 17428                 NaN                    NaN                NaN
# 17429                 NaN                    NaN                NaN
# 17430                 NaN                    NaN                NaN
# 17431                 NaN                    NaN                NaN
#
#        hydro_elec_per_capita  hydro_energy_per_capita
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 17427                357.582                      NaN
# 17428                210.620                      NaN
# 17429                275.971                      NaN
# 17430                346.284                      NaN
# 17431                342.779                      NaN
#
# [17432 rows x 8 columns]

# %%
other_renewable_cols = [col for col in ourworldindata.columns if 'other_renewable' in col]
ourworldindata_o_renew = ourworldindata[other_renewable_cols]
ourworldindata_o_renew
# Out:
#        other_renewable_electricity  other_renewable_exc_biofuel_electricity  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
# ...                            ...                                      ...
# 17427                        0.128                                      0.0
# 17428                        0.147                                      0.0
# 17429                        0.151                                      0.0
# 17430                        0.187                                      0.0
# 17431                        0.207                                      0.0
#
#        other_renewables_elec_per_capita  other_renewables_share_elec  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# ...                                 ...                          ...
# 17427                             9.265                        1.363
# 17428                            10.478                        2.154
# 17429                            10.606                        2.066
# 17430                            12.951                        2.048
# 17431                            14.112                        2.285
#
#        other_renewables_cons_change_pct  other_renewables_share_energy  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
# ...                                 ...                            ...
# 17427                               NaN                            NaN
# 17428                               NaN                            NaN
# 17429                               NaN                            NaN
# 17430                               NaN                            NaN
# 17431                               NaN                            NaN
#
#        other_renewables_cons_change_twh  other_renewable_consumption  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# ...                                 ...                          ...
# 17427                               NaN                          NaN
# 17428                               NaN                          NaN
# 17429                               NaN                          NaN
# 17430                               NaN                          NaN
# 17431                               NaN                          NaN
#
#        other_renewables_energy_per_capita
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 17427                                 NaN
# 17428                                 NaN
# 17429                                 NaN
# 17430                                 NaN
# 17431                                 NaN
#
# [17432 rows x 9 columns]

# %%
ourworldindata_renew = ourworldindata.filter(regex='^renewable')
ourworldindata_renew
# Out:
#        renewables_electricity  renewables_elec_per_capita  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# ...                       ...                         ...
# 17427                   5.076                     367.427
# 17428                   3.111                     221.739
# 17429                   4.091                     287.350
# 17430                   5.201                     360.205
# 17431                   5.241                     357.847
#
#        renewables_share_elec  renewables_cons_change_pct  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 17427                 54.070                         NaN
# 17428                 45.577                         NaN
# 17429                 55.968                         NaN
# 17430                 56.947                         NaN
# 17431                 57.933                         NaN
#
#        renewables_share_energy  renewables_cons_change_twh  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 17427                      NaN                         NaN
# 17428                      NaN                         NaN
# 17429                      NaN                         NaN
# 17430                      NaN                         NaN
# 17431                      NaN                         NaN
#
#        renewables_consumption  renewables_energy_per_capita
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ...                       ...                           ...
# 17427                     NaN                           NaN
# 17428                     NaN                           NaN
# 17429                     NaN                           NaN
# 17430                     NaN                           NaN
# 17431                     NaN                           NaN
#
# [17432 rows x 8 columns]

# %%
ourworldindata_solar = ourworldindata.filter(regex='solar')
ourworldindata_solar
# Out:
#        solar_electricity  solar_share_elec  solar_cons_change_pct  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# ...                  ...               ...                    ...
# 17427              0.008             0.085                    NaN
# 17428              0.009             0.132                    NaN
# 17429              0.011             0.150                    NaN
# 17430              0.014             0.153                    NaN
# 17431              0.014             0.155                    NaN
#
#        solar_share_energy  solar_cons_change_twh  solar_consumption  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
# ...                   ...                    ...                ...
# 17427                 NaN                    NaN                NaN
# 17428                 NaN                    NaN                NaN
# 17429                 NaN                    NaN                NaN
# 17430                 NaN                    NaN                NaN
# 17431                 NaN                    NaN                NaN
#
#        solar_elec_per_capita  solar_energy_per_capita
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 17427                  0.579                      NaN
# 17428                  0.641                      NaN
# 17429                  0.773                      NaN
# 17430                  0.970                      NaN
# 17431                  0.956                      NaN
#
# [17432 rows x 8 columns]

# %%
ourworldindata_wind = ourworldindata.filter(regex='wind')
ourworldindata_wind
# Out:
#        wind_electricity  wind_share_elec  wind_cons_change_pct  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   NaN              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   NaN              NaN                   NaN
# ...                 ...              ...                   ...
# 17427               0.0              0.0                   NaN
# 17428               0.0              0.0                   NaN
# 17429               0.0              0.0                   NaN
# 17430               0.0              0.0                   NaN
# 17431               0.0              0.0                   NaN
#
#        wind_share_energy  wind_cons_change_twh  wind_consumption  \
# 0                    NaN                   NaN               NaN
# 1                    NaN                   NaN               NaN
# 2                    NaN                   NaN               NaN
# 3                    NaN                   NaN               NaN
# 4                    NaN                   NaN               NaN
# ...                  ...                   ...               ...
# 17427                NaN                   NaN               NaN
# 17428                NaN                   NaN               NaN
# 17429                NaN                   NaN               NaN
# 17430                NaN                   NaN               NaN
# 17431                NaN                   NaN               NaN
#
#        wind_elec_per_capita  wind_energy_per_capita
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ...                     ...                     ...
# 17427                   0.0                     NaN
# 17428                   0.0                     NaN
# 17429                   0.0                     NaN
# 17430                   0.0                     NaN
# 17431                   0.0                     NaN
#
# [17432 rows x 8 columns]

# %%
ourworldindata_sev_values = ourworldindata.filter(['iso_code', 'country', 'year', 'electricity_generation', 'primary_energy_consumption'])
ourworldindata_sev_values
# Out:
#       iso_code      country  year  electricity_generation  \
# 0          AFG  Afghanistan  1900                     NaN
# 1          AFG  Afghanistan  1901                     NaN
# 2          AFG  Afghanistan  1902                     NaN
# 3          AFG  Afghanistan  1903                     NaN
# 4          AFG  Afghanistan  1904                     NaN
# ...        ...          ...   ...                     ...
# 17427      ZWE     Zimbabwe  2015                   9.388
# 17428      ZWE     Zimbabwe  2016                   6.826
# 17429      ZWE     Zimbabwe  2017                   7.310
# 17430      ZWE     Zimbabwe  2018                   9.133
# 17431      ZWE     Zimbabwe  2019                   9.046
#
#        primary_energy_consumption
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 17427                      55.642
# 17428                      47.500
# 17429                         NaN
# 17430                         NaN
# 17431                         NaN
#
# [17432 rows x 5 columns]

# %% [markdown]
# Filtering out the electricity production

# %%
ourworldindata_biofuel = ourworldindata.filter(regex='biofuel_electricity')
ourworldindata_hydro = ourworldindata.filter(regex='hydro_electricity')
ourworldindata_o_renew = ourworldindata.filter(regex='other_renewable_electricity')
ourworldindata_renew = ourworldindata.filter(regex='renewables_electricity')
ourworldindata_solar = ourworldindata.filter(regex='solar_electricity')
ourworldindata_wind = ourworldindata.filter(regex='wind_electricity')

# %%
df_to_merge = [ourworldindata_wind, ourworldindata_biofuel, ourworldindata_solar, ourworldindata_hydro, ourworldindata_o_renew, ourworldindata_renew]
owid = ourworldindata_sev_values.join(ourworldindata_wind.join(ourworldindata_biofuel.join(ourworldindata_solar.join(ourworldindata_hydro.join(ourworldindata_o_renew.join(ourworldindata_renew))))))
owid
# Out:
#       iso_code      country  year  electricity_generation  \
# 0          AFG  Afghanistan  1900                     NaN
# 1          AFG  Afghanistan  1901                     NaN
# 2          AFG  Afghanistan  1902                     NaN
# 3          AFG  Afghanistan  1903                     NaN
# 4          AFG  Afghanistan  1904                     NaN
# ...        ...          ...   ...                     ...
# 17427      ZWE     Zimbabwe  2015                   9.388
# 17428      ZWE     Zimbabwe  2016                   6.826
# 17429      ZWE     Zimbabwe  2017                   7.310
# 17430      ZWE     Zimbabwe  2018                   9.133
# 17431      ZWE     Zimbabwe  2019                   9.046
#
#        primary_energy_consumption  wind_electricity  biofuel_electricity  \
# 0                             NaN               NaN                  NaN
# 1                             NaN               NaN                  NaN
# 2                             NaN               NaN                  NaN
# 3                             NaN               NaN                  NaN
# 4                             NaN               NaN                  NaN
# ...                           ...               ...                  ...
# 17427                      55.642               0.0                0.128
# 17428                      47.500               0.0                0.147
# 17429                         NaN               0.0                0.151
# 17430                         NaN               0.0                0.187
# 17431                         NaN               0.0                0.207
#
#        other_renewable_exc_biofuel_electricity  solar_electricity  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
# ...                                        ...                ...
# 17427                                      0.0              0.008
# 17428                                      0.0              0.009
# 17429                                      0.0              0.011
# 17430                                      0.0              0.014
# 17431                                      0.0              0.014
#
#        hydro_electricity  other_renewable_electricity  renewables_electricity
# 0                    NaN                          NaN                     NaN
# 1                    NaN                          NaN                     NaN
# 2                    NaN                          NaN                     NaN
# 3                    NaN                          NaN                     NaN
# 4                    NaN                          NaN                     NaN
# ...                  ...                          ...                     ...
# 17427              4.940                        0.128                   5.076
# 17428              2.955                        0.147                   3.111
# 17429              3.929                        0.151                   4.091
# 17430              5.000                        0.187                   5.201
# 17431              5.020                        0.207                   5.241
#
# [17432 rows x 12 columns]

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### Missing values:

# %% [markdown]
# #### Years

# %% [markdown]
# almost no values until 1965

# %%
owid = owid.query('year>=2000').reset_index()

# %%
owid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4853 entries, 0 to 4852
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   index                                    4853 non-null   int64
#  1   iso_code                                 4368 non-null   object
#  2   country                                  4853 non-null   object
#  3   year                                     4853 non-null   int64
#  4   electricity_generation                   4649 non-null   float64
#  5   primary_energy_consumption               4331 non-null   float64
#  6   wind_electricity                         4649 non-null   float64
#  7   biofuel_electricity                      4249 non-null   float64
#  8   other_renewable_exc_biofuel_electricity  4249 non-null   float64
#  9   solar_electricity                        4649 non-null   float64
#  10  hydro_electricity                        4649 non-null   float64
#  11  other_renewable_electricity              4629 non-null   float64
#  12  renewables_electricity                   4629 non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 493.0+ KB

# %% [markdown]
# #### Iso_codes

# %%
arr = np.array(np.where(pd.isnull(owid.filter(['iso_code', 'country'])))).tolist()
arr_list = arr[0]

# %%
owid.iloc[arr_list,[1,2]].drop_duplicates()
# Out:
#      iso_code                        country
# 20        NaN                         Africa
# 201       NaN                   Asia Pacific
# 671       NaN                            CIS
# 809       NaN                Central America
# 1093      NaN                 Czechoslovakia
# 1211      NaN                 Eastern Africa
# 1389      NaN                         Europe
# 1409      NaN                 Europe (other)
# 1446      NaN              Falkland Islands
# 2679      NaN                  Middle Africa
# 2699      NaN                    Middle East
# 3083      NaN                  North America
# 3181      NaN                           OPEC
# 3218      NaN           Other Asia & Pacific
# 3238      NaN                      Other CIS
# 3258      NaN                Other Caribbean
# 3278      NaN              Other Middle East
# 3298      NaN          Other Northern Africa
# 3318      NaN            Other South America
# 3338      NaN          Other Southern Africa
# 3583      NaN                        Reunion
# 4009      NaN        South & Central America
# 4576      NaN  United States Pacific Islands
# 4715      NaN                 Western Africa
# 4796      NaN                     Yugoslavia

# %%
owid = owid.drop(axis=0, index=arr_list).reset_index()

# %%
owid = owid.drop(columns={'level_0', 'index'})
owid
# Out:
#      iso_code      country  year  electricity_generation  \
# 0         AFG  Afghanistan  2000                   0.467
# 1         AFG  Afghanistan  2001                   0.592
# 2         AFG  Afghanistan  2002                   0.687
# 3         AFG  Afghanistan  2003                   0.939
# 4         AFG  Afghanistan  2004                   0.894
# ...       ...          ...   ...                     ...
# 4363      ZWE     Zimbabwe  2015                   9.388
# 4364      ZWE     Zimbabwe  2016                   6.826
# 4365      ZWE     Zimbabwe  2017                   7.310
# 4366      ZWE     Zimbabwe  2018                   9.133
# 4367      ZWE     Zimbabwe  2019                   9.046
#
#       primary_energy_consumption  wind_electricity  biofuel_electricity  \
# 0                          5.777               0.0                0.000
# 1                          4.481               0.0                0.000
# 2                          4.262               0.0                0.000
# 3                          5.041               0.0                0.000
# 4                          4.669               0.0                0.000
# ...                          ...               ...                  ...
# 4363                      55.642               0.0                0.128
# 4364                      47.500               0.0                0.147
# 4365                         NaN               0.0                0.151
# 4366                         NaN               0.0                0.187
# 4367                         NaN               0.0                0.207
#
#       other_renewable_exc_biofuel_electricity  solar_electricity  \
# 0                                         0.0              0.000
# 1                                         0.0              0.000
# 2                                         0.0              0.000
# 3                                         0.0              0.000
# 4                                         0.0              0.000
# ...                                       ...                ...
# 4363                                      0.0              0.008
# 4364                                      0.0              0.009
# 4365                                      0.0              0.011
# 4366                                      0.0              0.014
# 4367                                      0.0              0.014
#
#       hydro_electricity  other_renewable_electricity  renewables_electricity
# 0                 0.312                        0.000                   0.312
# 1                 0.498                        0.000                   0.498
# 2                 0.555                        0.000                   0.555
# 3                 0.630                        0.000                   0.630
# 4                 0.565                        0.000                   0.565
# ...                 ...                          ...                     ...
# 4363              4.940                        0.128                   5.076
# 4364              2.955                        0.147                   3.111
# 4365              3.929                        0.151                   4.091
# 4366              5.000                        0.187                   5.201
# 4367              5.020                        0.207                   5.241
#
# [4368 rows x 12 columns]

# %% [markdown]
# #### electricity_generation

# %%
arr_eg = np.array(np.where(pd.isnull(owid['electricity_generation']))).tolist()
arr_eg_list = arr_eg[0]

# %%
owid.iloc[arr_eg_list,:]
# Out:
#      iso_code     country  year  electricity_generation  \
# 692       CPV  Cape Verde  2000                     NaN
# 693       CPV  Cape Verde  2001                     NaN
# 694       CPV  Cape Verde  2002                     NaN
# 695       CPV  Cape Verde  2003                     NaN
# 696       CPV  Cape Verde  2004                     NaN
# ...       ...         ...   ...                     ...
# 3895      TLS       Timor  2012                     NaN
# 3896      TLS       Timor  2013                     NaN
# 3897      TLS       Timor  2014                     NaN
# 3898      TLS       Timor  2015                     NaN
# 3899      TLS       Timor  2016                     NaN
#
#       primary_energy_consumption  wind_electricity  biofuel_electricity  \
# 692                        1.366               NaN                  NaN
# 693                        1.521               NaN                  NaN
# 694                        1.654               NaN                  NaN
# 695                        1.644               NaN                  NaN
# 696                        1.798               NaN                  NaN
# ...                          ...               ...                  ...
# 3895                       1.261               NaN                  NaN
# 3896                       1.900               NaN                  NaN
# 3897                       2.180               NaN                  NaN
# 3898                       2.138               NaN                  NaN
# 3899                       2.162               NaN                  NaN
#
#       other_renewable_exc_biofuel_electricity  solar_electricity  \
# 692                                       NaN                NaN
# 693                                       NaN                NaN
# 694                                       NaN                NaN
# 695                                       NaN                NaN
# 696                                       NaN                NaN
# ...                                       ...                ...
# 3895                                      NaN                NaN
# 3896                                      NaN                NaN
# 3897                                      NaN                NaN
# 3898                                      NaN                NaN
# 3899                                      NaN                NaN
#
#       hydro_electricity  other_renewable_electricity  renewables_electricity
# 692                 NaN                          NaN                     NaN
# 693                 NaN                          NaN                     NaN
# 694                 NaN                          NaN                     NaN
# 695                 NaN                          NaN                     NaN
# 696                 NaN                          NaN                     NaN
# ...                 ...                          ...                     ...
# 3895                NaN                          NaN                     NaN
# 3896                NaN                          NaN                     NaN
# 3897                NaN                          NaN                     NaN
# 3898                NaN                          NaN                     NaN
# 3899                NaN                          NaN                     NaN
#
# [119 rows x 12 columns]

# %%
owid.iloc[arr_eg_list,:]['country'].unique()
# Out:
# array(['Cape Verde', "Cote d'Ivoire", 'Eswatini', 'Faeroe Islands',
#        'Myanmar', 'Northern Mariana Islands', 'Timor'], dtype=object)

# %% [markdown]
# #### Fill NaN-values: The false values for electric generation are only in 7 countries; For the missing values in the other categories, the assumption is that there was no electricity produced

# %%
owid.fillna(0, inplace=True)

# %% [markdown]
# electricity unit: TWh
